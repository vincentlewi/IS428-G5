# %%
import pandas as pd

# %% [markdown]
# # hdb

# %%
hdb = pd.read_csv("Datasets/addresses_hdb.csv")
hdb.head()
# Out:
#                   QUERY                                          SEARCHVAL  \
# 0  309 ANG MO KIO AVE 1                                                NaN
# 1  216 ANG MO KIO AVE 1                                      ANG MO KIO 22
# 2  211 ANG MO KIO AVE 3           211 ANG MO KIO AVENUE 3 SINGAPORE 560211
# 3  202 ANG MO KIO AVE 3                              OCBC ANG MO KIO AVE 3
# 4  235 ANG MO KIO AVE 3  PCF SPARKLETOTS PRESCHOOL @ YIO CHU KANG BLK 2...
#
#   BLK_NO            ROAD_NAME  \
# 0    NaN                  NaN
# 1    216  ANG MO KIO AVENUE 1
# 2    211  ANG MO KIO AVENUE 3
# 3    202  ANG MO KIO AVENUE 3
# 4    235  ANG MO KIO AVENUE 3
#
#                                             BUILDING  \
# 0                                                NaN
# 1                                      ANG MO KIO 22
# 2                                                NIL
# 3                              OCBC ANG MO KIO AVE 3
# 4  PCF SPARKLETOTS PRESCHOOL @ YIO CHU KANG BLK 2...
#
# ...

# %%
hdb.shape
# Out:
# (9825, 11)

# %%
hdb_convert = hdb[["QUERY", "LATITUDE", "LONGITUDE"]]
hdb_convert.head()
# Out:
#                   QUERY  LATITUDE   LONGITUDE
# 0  309 ANG MO KIO AVE 1       NaN         NaN
# 1  216 ANG MO KIO AVE 1  1.366197  103.841505
# 2  211 ANG MO KIO AVE 3  1.369197  103.841667
# 3  202 ANG MO KIO AVE 3  1.368458  103.844515
# 4  235 ANG MO KIO AVE 3  1.366824  103.836491

# %%
hdb_convert.dropna(inplace=True)
hdb_convert.head()
# Out:
# /var/folders/fm/r45pd3w141dg56rt5cl8mht80000gn/T/ipykernel_7461/1998623441.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hdb_convert.dropna(inplace=True)
#                   QUERY  LATITUDE   LONGITUDE
# 1  216 ANG MO KIO AVE 1  1.366197  103.841505
# 2  211 ANG MO KIO AVE 3  1.369197  103.841667
# 3  202 ANG MO KIO AVE 3  1.368458  103.844515
# 4  235 ANG MO KIO AVE 3  1.366824  103.836491
# 5  232 ANG MO KIO AVE 3  1.368346  103.837196

# %%
hdb_convert.shape
# Out:
# (9688, 3)

# %%
hdb_convert.to_json("json/hdb.json", orient='records')

# %% [markdown]
# # Private

# %%
private = pd.read_csv("Datasets/addresses.csv")
private.head()
# Out:
#                           QUERY      SEARCHVAL BLK_NO        ROAD_NAME  \
# 0    THE TRUMPS JALAN KEMBANGAN     THE TRUMPS      1  JALAN KEMBANGAN
# 1  PARC RIVIERA WEST COAST VALE   PARC RIVIERA    101  WEST COAST VALE
# 2       D'LEEDON LEEDON HEIGHTS       D'LEEDON      1   LEEDON HEIGHTS
# 3      368 THOMSON THOMSON ROAD    368 THOMSON    368     THOMSON ROAD
# 4  ONE LEICESTER LEICESTER ROAD  ONE LEICESTER      1   LEICESTER ROAD
#
#         BUILDING                                            ADDRESS  POSTAL  \
# 0     THE TRUMPS      1 JALAN KEMBANGAN THE TRUMPS SINGAPORE 419154  419154
# 1   PARC RIVIERA  101 WEST COAST VALE PARC RIVIERA SINGAPORE 126753  126753
# 2       D'LEEDON         1 LEEDON HEIGHTS D'LEEDON SINGAPORE 267939  267939
# 3    368 THOMSON      368 THOMSON ROAD 368 THOMSON SINGAPORE 298127  298127
# 4  ONE LEICESTER    1 LEICESTER ROAD ONE LEICESTER SINGAPORE 358828  358828
#
#               X             Y  LATITUDE   LONGITUDE
# ...

# %%
private = private [["QUERY", "LATITUDE", "LONGITUDE"]]
private.head()
# Out:
#                           QUERY  LATITUDE   LONGITUDE
# 0    THE TRUMPS JALAN KEMBANGAN  1.320026  103.913487
# 1  PARC RIVIERA WEST COAST VALE  1.320818  103.752667
# 2       D'LEEDON LEEDON HEIGHTS  1.316090  103.802300
# 3      368 THOMSON THOMSON ROAD  1.327091  103.841979
# 4  ONE LEICESTER LEICESTER ROAD  1.329431  103.867357

# %%
private.to_json("json/private.json", orient="records")

# %% [markdown]
# # School

# %%
school = pd.read_csv(Datasets/)
